# %% [markdown]
# # 📊 Workspace with Python 2.7 installed
#
# This image is based on Python 3.11 installed on Debian Bullseye. You can use Python 2.7 using the "Python 2.7" tile from the JupyterLab launcher.
#
# To verify you are using the right kernel, with the right Python version, you can run the following inside your notebook opened through the tile with using the kernel from your conda environment:
#
# ```python
# import sys
# !{sys.executable} --version
# ```
#
# If you'd like to use Python 2.7 the output should be: "Python 2.7.18"
#
# -------------------------
#
# ## 📥️ Install dependencies
#
#
#
# ### 🐍 Install pip packages
#
# Install Python packages with `pip`:
#
#
# ```bash
# pip install -r requirements.txt
# ```
#
#
# ### 📦️ Install apt packages
#
# You can install packages with the `apt` package manager:
#
#
# ```bash
# apt install -y wget
# ```
#
#
# -------------------------
#
# ## ℹ️ About the image
#
# You can find more details about this container image at https://github.com/MaastrichtU-IDS/jupyterlab/tree/main/python2.7
